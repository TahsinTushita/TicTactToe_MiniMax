# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv('F:/Study Materials/4 - 2/AI/AQI_dataset/aqi_dataset.csv')
dataset
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 28469  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 28470  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 28471  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 28472  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 28473  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN           NaN
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN           NaN
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN           NaN
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN           NaN
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN           NaN
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 28469   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 28470   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 28471   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 28472   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 28473   0.59   2.10   17.05      NaN      NaN     NaN  50.0          Good
#
# [28474 rows x 16 columns]

# %%
dataset.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  23920.000000  17465.000000  25011.000000  24966.000000  24330.000000
# mean      69.095223    121.578966     17.857667     28.959424     32.737994
# std       65.389862     90.987310     22.585057     24.655411     31.809871
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       29.937500     59.900000      5.760000     11.982500     12.900000
# 50%       50.215000     98.820000     10.080000     22.110000     23.910000
# 75%       82.557500    152.970000     20.450000     38.050000     40.807500
# max      949.990000   1000.000000    351.300000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  18335.000000  26452.000000  24674.000000  24526.000000  22964.000000
# mean      23.894052      2.306848     14.758950     34.519763      3.310998
# std       26.087108      7.088831     18.442412     21.763107     16.001572
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%        8.710000      0.520000      5.640000     18.872500      0.150000
# 50%       16.170000      0.905000      9.220000     30.835000      1.120000
# 75%       30.445000      1.470000     15.560000     45.540000      3.160000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI
# count  20635.000000  11239.000000  23894.000000
# mean       8.918763      3.063745    170.145811
# std       20.241362      6.356428    142.084468
# min        0.000000      0.000000     13.000000
# 25%        0.710000      0.140000     83.000000
# 50%        3.100000      0.980000    121.000000
# 75%        9.360000      3.340000    215.000000
# max      454.850000    170.370000   2049.000000

# %%
dataset.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4554
# PM10          11009
# NO             3463
# NO2            3508
# NOx            4144
# NH3           10139
# CO             2022
# SO2            3800
# O3             3948
# Benzene        5510
# Toluene        7839
# Xylene        17235
# AQI            4580
# AQI_Bucket     4580
# dtype: int64

# %%
dataset = dataset.fillna(dataset.mean())

# %%
dataset.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5            0
# PM10             0
# NO               0
# NO2              0
# NOx              0
# NH3              0
# CO               0
# SO2              0
# O3               0
# Benzene          0
# Toluene          0
# Xylene           0
# AQI              0
# AQI_Bucket    4580
# dtype: int64

# %%
df = pd.DataFrame(dataset)
df
# Out:
#                 City        Date      PM2.5        PM10     NO    NO2    NOx  \
# 0          Ahmedabad  2015-01-01  69.095223  121.578966   0.92  18.22  17.15
# 1          Ahmedabad  2015-01-02  69.095223  121.578966   0.97  15.69  16.46
# 2          Ahmedabad  2015-01-03  69.095223  121.578966  17.40  19.30  29.70
# 3          Ahmedabad  2015-01-04  69.095223  121.578966   1.70  18.48  17.97
# 4          Ahmedabad  2015-01-05  69.095223  121.578966  22.10  21.42  37.76
# ...              ...         ...        ...         ...    ...    ...    ...
# 28469  Visakhapatnam  2020-06-27  15.020000   50.940000   7.68  25.06  19.54
# 28470  Visakhapatnam  2020-06-28  24.380000   74.090000   3.42  26.06  16.53
# 28471  Visakhapatnam  2020-06-29  22.910000   65.730000   3.45  29.53  18.33
# 28472  Visakhapatnam  2020-06-30  16.640000   49.970000   4.05  29.26  18.80
# 28473  Visakhapatnam  2020-07-01  15.000000   66.000000   0.40  26.85  14.05
#
#              NH3     CO    SO2      O3   Benzene    Toluene    Xylene  \
# 0      23.894052   0.92  27.64  133.36  0.000000   0.020000  0.000000
# 1      23.894052   0.97  24.55   34.06  3.680000   5.500000  3.770000
# 2      23.894052  17.40  29.07   30.70  6.800000  16.400000  2.250000
# 3      23.894052   1.70  18.59   36.08  4.430000  10.140000  1.000000
# 4      23.894052  22.10  39.33   39.31  7.010000  18.890000  2.780000
# ...          ...    ...    ...     ...       ...        ...       ...
# 28469  12.470000   0.47   8.55   23.30  2.240000  12.070000  0.730000
# 28470  11.990000   0.52  12.72   30.14  0.740000   2.210000  0.380000
# 28471  10.710000   0.48   8.42   30.96  0.010000   0.010000  0.000000
# 28472  10.030000   0.52   9.84   28.30  0.000000   0.000000  0.000000
# 28473   5.200000   0.59   2.10   17.05  3.310998   8.918763  3.063745
#
#               AQI    AQI_Bucket
# 0      170.145811           NaN
# 1      170.145811           NaN
# 2      170.145811           NaN
# 3      170.145811           NaN
# 4      170.145811           NaN
# ...           ...           ...
# 28469   41.000000          Good
# 28470   70.000000  Satisfactory
# 28471   68.000000  Satisfactory
# 28472   54.000000  Satisfactory
# 28473   50.000000          Good
#
# [28474 rows x 16 columns]

# %%
del df['City']

# %%
del df['Date']

# %%
del df['AQI_Bucket']

# %%
df
# Out:
#            PM2.5        PM10     NO    NO2    NOx        NH3     CO    SO2  \
# 0      69.095223  121.578966   0.92  18.22  17.15  23.894052   0.92  27.64
# 1      69.095223  121.578966   0.97  15.69  16.46  23.894052   0.97  24.55
# 2      69.095223  121.578966  17.40  19.30  29.70  23.894052  17.40  29.07
# 3      69.095223  121.578966   1.70  18.48  17.97  23.894052   1.70  18.59
# 4      69.095223  121.578966  22.10  21.42  37.76  23.894052  22.10  39.33
# ...          ...         ...    ...    ...    ...        ...    ...    ...
# 28469  15.020000   50.940000   7.68  25.06  19.54  12.470000   0.47   8.55
# 28470  24.380000   74.090000   3.42  26.06  16.53  11.990000   0.52  12.72
# 28471  22.910000   65.730000   3.45  29.53  18.33  10.710000   0.48   8.42
# 28472  16.640000   49.970000   4.05  29.26  18.80  10.030000   0.52   9.84
# 28473  15.000000   66.000000   0.40  26.85  14.05   5.200000   0.59   2.10
#
#            O3   Benzene    Toluene    Xylene         AQI
# 0      133.36  0.000000   0.020000  0.000000  170.145811
# 1       34.06  3.680000   5.500000  3.770000  170.145811
# 2       30.70  6.800000  16.400000  2.250000  170.145811
# 3       36.08  4.430000  10.140000  1.000000  170.145811
# 4       39.31  7.010000  18.890000  2.780000  170.145811
# ...       ...       ...        ...       ...         ...
# 28469   23.30  2.240000  12.070000  0.730000   41.000000
# 28470   30.14  0.740000   2.210000  0.380000   70.000000
# 28471   30.96  0.010000   0.010000  0.000000   68.000000
# 28472   28.30  0.000000   0.000000  0.000000   54.000000
# 28473   17.05  3.310998   8.918763  3.063745   50.000000
#
# [28474 rows x 13 columns]

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
dataset.isnull().sum()
# Out:
# PM2.5      0
# PM10       0
# NO         0
# NO2        0
# NOx        0
# NH3        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# AQI        0
# dtype: int64

# %%
df
# Out:
#            PM2.5        PM10     NO    NO2    NOx        NH3     CO    SO2  \
# 0      69.095223  121.578966   0.92  18.22  17.15  23.894052   0.92  27.64
# 1      69.095223  121.578966   0.97  15.69  16.46  23.894052   0.97  24.55
# 2      69.095223  121.578966  17.40  19.30  29.70  23.894052  17.40  29.07
# 3      69.095223  121.578966   1.70  18.48  17.97  23.894052   1.70  18.59
# 4      69.095223  121.578966  22.10  21.42  37.76  23.894052  22.10  39.33
# ...          ...         ...    ...    ...    ...        ...    ...    ...
# 28469  15.020000   50.940000   7.68  25.06  19.54  12.470000   0.47   8.55
# 28470  24.380000   74.090000   3.42  26.06  16.53  11.990000   0.52  12.72
# 28471  22.910000   65.730000   3.45  29.53  18.33  10.710000   0.48   8.42
# 28472  16.640000   49.970000   4.05  29.26  18.80  10.030000   0.52   9.84
# 28473  15.000000   66.000000   0.40  26.85  14.05   5.200000   0.59   2.10
#
#            O3   Benzene    Toluene    Xylene         AQI
# 0      133.36  0.000000   0.020000  0.000000  170.145811
# 1       34.06  3.680000   5.500000  3.770000  170.145811
# 2       30.70  6.800000  16.400000  2.250000  170.145811
# 3       36.08  4.430000  10.140000  1.000000  170.145811
# 4       39.31  7.010000  18.890000  2.780000  170.145811
# ...       ...       ...        ...       ...         ...
# 28469   23.30  2.240000  12.070000  0.730000   41.000000
# 28470   30.14  0.740000   2.210000  0.380000   70.000000
# 28471   30.96  0.010000   0.010000  0.000000   68.000000
# 28472   28.30  0.000000   0.000000  0.000000   54.000000
# 28473   17.05  3.310998   8.918763  3.063745   50.000000
#
# [28474 rows x 13 columns]

# %%
df_x = df.iloc[:,0:12]
df_y = df['AQI']
df_x.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  28474.000000  28474.000000  28474.000000  28474.000000  28474.000000
# mean      69.095223    121.578966     17.857667     28.959424     32.737994
# std       59.932903     71.258401     21.167103     23.086677     29.404068
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       33.480000     84.020000      6.360000     13.250000     14.810000
# 50%       60.040000    121.578966     11.780000     25.770000     28.010000
# 75%       73.975000    121.578966     17.957500     35.090000     36.500000
# max      949.990000   1000.000000    351.300000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  28474.000000  28474.000000  28474.000000  28474.000000  28474.000000
# mean      23.894052      2.306848     14.758950     34.519763      3.310998
# std       20.933312      6.832491     17.167699     20.198020     14.370119
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%       12.312500      0.550000      6.090000     20.800000      0.280000
# 50%       23.894052      0.970000     10.650000     34.519763      1.945000
# 75%       23.894052      1.750000     14.758950     42.610000      3.310998
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene
# count  28474.000000  28474.000000
# mean       8.918763      3.063745
# std       17.231173      3.993384
# min        0.000000      0.000000
# 25%        1.422500      1.980000
# 50%        7.200000      3.063745
# 75%        8.918763      3.063745
# max      454.850000    170.370000

# %%
df_y
# Out:
# 0        170.145811
# 1        170.145811
# 2        170.145811
# 3        170.145811
# 4        170.145811
#             ...
# 28469     41.000000
# 28470     70.000000
# 28471     68.000000
# 28472     54.000000
# 28473     50.000000
# Name: AQI, Length: 28474, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(df_x, df_y, test_size=0.4,random_state = 0)

# %%
from sklearn.neural_network import MLPRegressor
reg = MLPRegressor(hidden_layer_sizes=(16,16),activation='relu',solver='adam',max_iter=300)

# %%
reg.fit(x_train, y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(16, 16), max_iter=300)

# %%
predicted_aqi = reg.predict(x_test)

# %%
predicted_aqi
# Out:
# array([359.75567818, 145.19523619, 157.16835634, ..., 172.35469344,
#        152.22229015, 113.4249003 ])

# %%
real_aqi_array = np.array(y_test)
predicted_aqi_array = np.array(predicted_aqi)
df1 = pd.DataFrame({"real": real_aqi_array, "predictions": predicted_aqi_array})
df1.head(100)
# Out:
#           real  predictions
# 0   466.000000   359.755678
# 1   170.145811   145.195236
# 2   151.000000   157.168356
# 3   169.000000   103.105533
# 4   237.000000   277.395293
# ..         ...          ...
# 95  170.145811   161.057514
# 96  190.000000   147.748865
# 97  200.000000   176.035665
# 98  191.000000   107.313575
# 99  385.000000   404.772181
#
# [100 rows x 2 columns]

# %%
ax = df1.plot.scatter(x="real",y=0, color="DarkBlue", label="Real")
df1.plot.scatter(x=0, y="predictions", color="DarkGreen", label="Predictions", ax=ax)

# %%
np.mean((predicted_aqi-y_test)**2)
# Out:
# 2747.8528408579

# %%
reg.score(x_test,y_test)*100
# Out:
# 83.33522888159514
